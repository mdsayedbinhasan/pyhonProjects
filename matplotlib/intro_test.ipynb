# %%
import matplotlib as mpl

# %%
mpl.__version__
# Out:
# '3.1.0'

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4],[5,6,7,8])
plt.show()

# %%
plt.plot([1,2,3,4],[5,6,7,8])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.plot([1,2,3,4],[5,6,7,8])
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("first plot")
plt.show()
