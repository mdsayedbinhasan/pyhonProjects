# %%
import matplotlib.pyplot as plt

# %%
x=[34,67,23,26,29,40,31,55,42,45,48,50,52,53,57,59,18,20,22,23,25,49,39]
plt.hist(x, ec="red")
plt.xlabel("age")
plt.ylabel("count")
plt.title("population age count")
plt.show()

# %%
x=[34,67,23,26,29,40,31,55,42,45,48,50,52,53,57,59,18,20,22,23,25,49,39]
plt.hist(x,6, ec="red")
plt.xlabel("age")
plt.ylabel("count")
plt.title("population age count")
plt.show()

# %%
x=[34,67,2,5,10,13,23,26,29,40,31,55,42,45,48,70,78,69,50,52,53,57,59,18,20,22,23,25,49,39]
y=[1,7,20,30,40,50,60,70,80,90]
plt.hist(x,y, ec="red")
plt.xlabel("age")
plt.ylabel("count")
plt.title("population age count")
plt.show()

# %%
x=[34,67,2,5,10,13,23,26,29,40,31,55,42,45,48,70,78,69,50,52,53,57,59,18,20,22,23,25,49,39]
y=[1,7,15,20,30,40,50,60,70,80,90]
plt.hist(x,y, ec="red")
plt.xlabel("age")
plt.ylabel("count")
plt.title("population age count")
plt.xticks(y)
plt.show()

# %%
x=[34,67,2,5,10,13,23,26,29,40,31,55,42,45,48,70,78,69,50,52,53,57,59,18,20,22,23,25,49,39]

plt.hist(x,"auto", ec="red")
plt.xlabel("age")
plt.ylabel("count")
plt.title("population age count")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x=np.random.randn(1000)
n,m,patches=plt.hist(x,bins=10)
color=["red", "green", "blue", "cyan", "#c11325", "#222222", "#000000", "#c11692", "#f45805", "#c21805"]
for i in range(len(n)):
    c=color[i]
    patches[i].set_fc(c)
plt.xlabel("age")
plt.ylabel("people count")
plt.title("hist color change of bar")
plt.show()
