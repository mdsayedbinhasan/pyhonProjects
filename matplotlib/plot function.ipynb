# %%
import matplotlib.pyplot as plt

# %%
plt.plot([10,20,30,40], "g", linewidth=20)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("first plot")
plt.show()

# %%
plt.plot([10,20,30,40], "g")
plt.plot([8,21,3,15], "r")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("first plot")
plt.show()
