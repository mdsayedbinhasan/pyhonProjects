# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv')
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2           4.0        6     1.0
# 1         102  yes      3          5           2.0        8     2.0
# 2         103  yes      3          7           5.0        1     6.0
# 3         104  yes      2          4           2.0        7     5.0
# 4         105  yes      8         32           NaN        4     NaN
#
#    percentage
# 0          55
# 1          23
# 2          34
# 3          45
# 4          21

# %%
df = pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv', na_values = 'not number')
df
# Out:
#    student id date  class  study hrs sleeping hrs  smu hrs  mg hrs  percentage
# 0         101  yes     10          2            4        6     1.0          55
# 1         102  yes      3          5            2        8     2.0          23
# 2         103  yes      3          7            5        1     6.0          34
# 3         104  yes      2          4            2        7     5.0          45
# 4         105  yes      8         32    no values        4     NaN          21

# %%
df = pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv', na_values = 'not number')
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2             4        6       1
# 1         102  yes      3          5             2        8       2
# 2         103  yes      3          7             5        1       6
# 3         104  yes      2          4             2        7       5
# 4         105  yes      8         32             5        4       3
#
#    percentage
# 0          55
# 1          23
# 2          34
# 3          45
# 4          21

# %%
df = pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv', keep_default_na = False)
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2             4        6       1
# 1         102  yes      3          5             2        8       2
# 2         103  yes      3          7             5        1       6
# 3         104  yes      2          4             2        7       5
# 4         105  yes      8         32             5        4       3
#
#    percentage
# 0          55
# 1          23
# 2          34
# 3          45
# 4          21

# %%
df = pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv', na_filter = False)
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2             4        6       1
# 1         102  yes      3          5             2        8       2
# 2         103  yes      3          7             5        1       6
# 3         104  yes      2          4             2        7       5
# 4         105  yes      8         32             5        4       3
#
#    percentage
# 0          55
# 1          23
# 2          34
# 3          45
# 4          21

# %%
import pandas as pd

# %%
pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv')
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2             4        6       1
# 1         102  yes      3          5             2        8       2
# 2         103  yes      3          7             5        1       6
# 3         104  yes      2          4             2        7       5
# 4         105  yes      8         32             5        4       3
#
#    percentage
# 0          55
# 1          23
# 2          34
# 3          45
# 4          21

# %%
df.isnull()
# Out:
#    student id   date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0       False  False  False      False         False    False   False
# 1       False  False  False      False         False    False   False
# 2       False  False  False      False         False    False   False
# 3       False  False  False      False         False    False   False
# 4       False  False  False      False         False    False   False
#
#    percentage
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False

# %%
pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv')
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2             4        6       1
# 1         102  yes      3          5             2        8       2
# 2         103  yes      3          7             5        1       6
# 3         104  yes      2          4             2        7       5
# 4         105  yes      8         32             5        4       3
#
#    percentage
# 0          55
# 1          23
# 2          34
# 3          45
# 4          21

# %%
df = pd.read_csv('C://Users//sayed//Desktop//python_project//pandas_practical/file1.csv')
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2           4.0        6       1
# 1         102  yes      3          5           2.0        8       2
# 2         103  yes      3          7           NaN        1       6
# 3         104  yes      2          4           2.0        7       5
# 4         105  yes      8         32           5.0        4       3
#
#    percentage
# 0        55.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4        21.0

# %%
df.isnull()
# Out:
#    student id   date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0       False  False  False      False         False    False   False
# 1       False  False  False      False         False    False   False
# 2       False  False  False      False          True    False   False
# 3       False  False  False      False         False    False   False
# 4       False  False  False      False         False    False   False
#
#    percentage
# 0       False
# 1        True
# 2        True
# 3        True
# 4       False

# %%
df.isnull().sum().sum()
# Out:
# 4

# %%
#series
import numpy as np
sr = pd.Series([2, 5, 6, np.nan, 9, np.NaN])
sr
# Out:
# 0    2.0
# 1    5.0
# 2    6.0
# 3    NaN
# 4    9.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
import as pd
# Out:
#   File "<ipython-input-1-e2b2eb9c9632>", line 1
#     import as pd
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv('C://Users/sayed//python_projects//pandas_practical//file1.csv')
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2           4.0        6       1
# 1         102  yes      3          5           2.0        8       2
# 2         103  yes      3          7           NaN        1       6
# 3         104  yes      2          4           2.0        7       5
# 4         105  yes      8         32           5.0        4       3
#
#    percentage
# 0        55.0
# 1         NaN
# 2         NaN
# 3         NaN
# 4        21.0

# %%
df.dropna()
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2           4.0        6       1
# 4         105  yes      8         32           5.0        4       3
#
#    percentage
# 0        55.0
# 4        21.0

# %%
df.dropna(axis = 1)
# Out:
#    student id date  class  study hrs  smu hrs  mg hrs
# 0         101  yes     10          2        6       1
# 1         102  yes      3          5        8       2
# 2         103  yes      3          7        1       6
# 3         104  yes      2          4        7       5
# 4         105  yes      8         32        4       3

# %%
df.dropna(inplace=True)
df
# Out:
#    student id date  class  study hrs  sleeping hrs  smu hrs  mg hrs  \
# 0         101  yes     10          2           4.0        6       1
# 4         105  yes      8         32           5.0        4       3
#
#    percentage
# 0        55.0
# 4        21.0
